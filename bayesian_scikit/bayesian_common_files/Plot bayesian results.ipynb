# %% [markdown]
# # PLOTS

# %% [markdown]
# ##### change this line

# %%
configuration_name = "jess1"

# %% [markdown]
# ###### y.y

# %%
from skopt.plots import plot_convergence, plot_objective,plot_evaluations, partial_dependence
from utils.definitions import ROOT_DIR, load_obj
import os, sys
import skopt.plots
import matplotlib.pyplot as plt
from bayesian_scikit.bayesian_common_files.generic_bayesian import obiettivo

# %%
directory_results = ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/results_for_plotting/'
directory_plots = ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/plots/'

# %%
filenames = os.listdir(directory_results)
results = [[] for x in range(10)]

for i in range(0,10):
    if os.path.isfile(directory_results+'cat'+str(i+1)+'_RES.pkl'):
        results[i]= load_obj('cat'+str(i+1)+'_RES', directory_results)
        print("found cat"+str(i+1)+'_RES')
    else:
        results[i] = None
        print("THERE IS NO: "+str(i+1)+'_RES')
# Out:
# found cat1_RES
# found cat2_RES
# found cat3_RES
# found cat4_RES
# found cat5_RES
# found cat6_RES
# found cat7_RES
# found cat8_RES
# found cat9_RES
# found cat10_RES

# %%
print("cat1",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(1)+'_params_dict'))
print()
print("cat2",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(2)+'_params_dict'))
print()
print("cat3",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(3)+'_params_dict'))
print()
print("cat4",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(4)+'_params_dict'))
print()
print("cat5",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(5)+'_params_dict'))
print()
print("cat6",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(6)+'_params_dict'))
print()
print("cat7",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(7)+'_params_dict'))
print()
print("cat8",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(8)+'_params_dict'))
print()
print("cat9",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(9)+'_params_dict'))
print()
print("cat10",load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(10)+'_params_dict'))
# Out:
# cat1 {'nlp_fusion': 69.44306360385193, 'top_pop': 1.9789490702446626}
#
# cat2 {'cb_al_ar': 0.0, 'top_pop_album_cat2': 0.0, 'cb_al': 0.0, 'cf_tom_artist': 100.0, 'cf_tom_album': 0.0, 'nlp_fusion': 66.43324612794348, 'cf_ib_new': 100.0, 'cf_ub_new': 100.0, 'cb_ar': 0.0}
#
# cat3 {'cb_al_ar': 0.0, 'cb_al': 0.0, 'nlp_fusion': 37.39419896831338, 'cf_ib_new': 100.0, 'cf_ub_new': 70.52205126453114, 'cb_ar': 16.086380940998644}
#
# cat4 {'cb_al_ar': 0.0, 'cb_al': 0.0, 'nlp_fusion': 100.0, 'cf_ib_new': 85.9128522534777, 'cf_ub_new': 49.13059903617885, 'cb_ar': 9.019147478893577}
#
# cat5 {'cb_al_ar': 0.0, 'cb_al': 0.0, 'nlp_fusion': 24.046357803106865, 'cf_ib_new': 100.0, 'cf_ub_new': 71.04732641937473, 'cb_ar': 13.1867534886745}
#
# cat6 {'cb_al_ar': 0.0, 'cb_al': 0.0, 'nlp_fusion': 0.0, 'cf_ib_new': 57.222037840731396, 'cf_ub_new': 76.65181739877754, 'cb_ar': 7.96168122986302}
#
# ...

# %% [markdown]
# # CAT 1

# %%
cat=1
a = plot_convergence(results[cat-1])

# %%
a = plot_objective(results[cat-1], n_points=20, n_samples=10)
print(load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(cat)+'_params_dict'))
# Out:
# {'nlp_fusion': 69.44306360385193, 'top_pop': 1.9789490702446626}

# %% [markdown]
# # CAT 2

# %%
cat=2
a = plot_convergence(results[cat-1])

# %%
a = plot_objective(results[cat-1], n_points=20, n_samples=10)
print(load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(cat)+'_params_dict'))
# Out:
# {'cb_al_ar': 0.0, 'top_pop_album_cat2': 0.0, 'cb_al': 0.0, 'cf_tom_artist': 100.0, 'cf_tom_album': 0.0, 'nlp_fusion': 66.43324612794348, 'cf_ib_new': 100.0, 'cf_ub_new': 100.0, 'cb_ar': 0.0}

# %% [markdown]
# # cat 3

# %%
cat=3 
a = plot_convergence(results[cat-1])

# %%
a = plot_objective(results[cat-1], n_points=20, n_samples=10)
print(load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(cat)+'_params_dict'))
# Out:
# {'cb_al': 0.0, 'cf_ub_new': 75.94929486001794, 'cb_al_ar': 15.294028601298896, 'cf_ib_new': 100.0, 'nlp_fusion': 42.500752670974165, 'cb_ar': 9.207498741280324}

# %% [markdown]
# # cat 4

# %%
a = plot_convergence(results[3])

# %%
a = plot_objective(results[3], n_points=20, n_samples=10)

# %% [markdown]
# # cat 5

# %%
a = plot_convergence(results[4])

# %%
a = plot_objective(results[4], n_points=20, n_samples=10)

# %% [markdown]
# # cat 6

# %%
cat=6 
a = plot_convergence(results[cat-1])

# %%
a = plot_objective(results[cat-1], n_points=20, n_samples=10)
print(load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(cat)+'_params_dict'))
# Out:
# {'cb_al': 0.0, 'cf_ub_new': 68.79755460600441, 'cb_al_ar': 0.0, 'cf_ib_new': 52.005202069670496, 'nlp_fusion': 100.0, 'cb_ar': 7.591400377298281}

# %% [markdown]
# # CAT 7

# %%
cat=7
a = plot_convergence(results[6])

# %%
a = plot_objective(results[cat-1], n_points=20, n_samples=10)
print(load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(cat)+'_params_dict'))
print("order:")
# Out:
# {'cb_al': 0.0, 'cf_ub_new': 100.0, 'cb_al_ar': 0.0, 'cf_ib_new': 100.0, 'nlp_fusion': 33.42782671248376, 'cb_ar': 8.83631003756537}

# %% [markdown]
# # cat 8

# %%
cat=8
a = plot_convergence(results[cat-1])

# %%
a = plot_objective(results[cat-1], n_points=20, n_samples=10)
print(load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(cat)+'_params_dict'))
# Out:
# {'cb_al_ar': 14.197925218156964, 'cb_al': 0.0, 'hyb_j_main_cat8': 100.0, 'nlp_fusion': 0.0, 'cf_ib_new': 42.20807807496701, 'cf_ub_new': 50.6766724227035, 'cb_ar': 8.617119170449653}

# %% [markdown]
# # cat 9

# %%
cat=9
a = plot_convergence(results[cat-1])

# %%
a = plot_objective(results[cat-1], n_points=20, n_samples=10)
print(load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(cat)+'_params_dict'))
# Out:
# {'cb_al': 0.0, 'cf_ub_new': 100.0, 'cb_al_ar': 0.0, 'cf_ib_new': 0.0, 'nlp_fusion': 0.0, 'cb_ib_cat9': 100.0, 'cb_ar': 21.680581063102995}

# %% [markdown]
# # cat 10

# %%
cat=10
a = plot_convergence(results[cat-1])

# %%
a = plot_objective(results[cat-1], n_points=20, n_samples=10)
print(load_obj(ROOT_DIR + '/bayesian_scikit/' + configuration_name + '/best_params/cat'+str(cat)+'_params_dict'))
# Out:
# {'hyb_j_main_cat10': 100.0, 'cb_al_ar': 18.181930728702916, 'cb_al': 0.0, 'nlp_fusion': 0.0, 'cf_ib_new': 61.86818078055367, 'cf_ub_new': 54.02858661162172, 'cb_ar': 0.0}
