# %%
import pandas as pd
import time
from Splitter import *


start = time.time()
print("Loading file:")
playlists = pd.read_csv("../spotify/playlists.csv", delimiter='\t')
interactions = pd.read_csv("../spotify/interactions.csv", delimiter='\t')
end = time.time()
print(str(end-start) + "s")

start = time.time()
print("Splitting dataset:")
train_playlists, train_interactions, test_playlists, test_interactions, \
    eval_interactions = split_dataset(playlists, interactions)
end = time.time()
print(str(end-start) + "s")
# Out:
# Loading file:
# 22.1892249584198s
# Splitting dataset:
# cat5 done
# cat7 done
# cat6 done
# cat4 done
# cat3 done
# cat10 done
# cat9 done
# cat8 done
# cat2 done
# cat1 done
# 334.3186078071594s

# %%
train_playlists.head(10)
# Out:
#                    name  collaborative  pid  modified_at  num_albums  \
# 0            Throwbacks          False    0   1493424000          47
# 1      Awesome Playlist          False    1   1506556800          23
# 2               korean           False    2   1505692800          51
# 3                   mat          False    3   1501027200         107
# 4                   90s          False    4   1401667200          16
# 5               Wedding          False    5   1430956800          71
# 6  I Put A Spell On You          False    6   1477094400          15
# 7                  2017          False    7   1509321600          52
# 8                   BOP          False    8   1508976000          37
# 9          old country           False    9   1501804800          20
#
#    num_tracks  num_followers  num_tracks.1  num_edits  duration_ms  \
# 0          52              1            52          6     11532414
# 1          39              1            39          5     11656470
# 2          64              1            64         18     14039958
# 3         126              1           126          4     28926058
# 4          17              2            17          7      4335282
# 5          80              1            80          3     19156557
# 6          16              1            16          2      3408479
# 7          53              1            53         38     12674796
# 8          46              2            46         21      9948921
# 9          21              1            21         10      4297488
#
#    num_artists description
# 0           37         NaN
# 1           21         NaN
# 2           31         NaN
# 3           86         NaN
# 4           16         NaN
# 5           56         NaN
# 6           13         NaN
# 7           48         NaN
# 8           23         NaN
# 9           18         NaN

# %%
train_interactions.head(10)
# Out:
#    pid  tid  pos
# 0    0    0    0
# 1    0    1    1
# 2    0    2    2
# 3    0    3    3
# 4    0    4    4
# 5    0    5    5
# 6    0    6    6
# 7    0    7    7
# 8    0    8    8
# 9    0    9    9

# %%
test_playlists.head()
# Out:
#           name  num_holdouts  num_samples  num_tracks     pid
# 0  Jesus music            48           10          58    1195
# 1       Sexual            78           10          88    1893
# 2      D.O.P.E            53           10          63  100197
# 3  road trips             84           10          94  100281
# 4        Turnt            30           10          40  100783

# %%
test_interactions.head()
# Out:
#     pid    tid  pos
# 0  1195  17729    0
# 1  1195  25893    1
# 2  1195   5831    2
# 3  1195   5786    3
# 4  1195  39543    4

# %%
eval_interactions.head()
# Out:
#     pid    tid  pos
# 0  1195  39546   10
# 1  1195  14579   11
# 2  1195  31875   12
# 3  1195   5782   13
# 4  1195  39547   14
